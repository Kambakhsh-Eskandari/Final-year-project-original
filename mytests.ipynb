# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from my_utils import log_img, normalize_image

from PIL import Image
from PIL import ImageFilter
import math

# %%
import tensorflow as tf
# Out:
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# WARNING:tensorflow:From C:\Users\Kambakhsh\AppData\Local\Temp\ipykernel_17452\1503887568.py:1: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Kambakhsh\AppData\Local\Temp\ipykernel_17452\1503887568.py:1: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17452\607749261.py in <module>
# ----> 1 print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#
# c:\Users\Kambakhsh\miniconda3\envs\FusionGAN\lib\site-packages\tensorflow\python\util\deprecation_wrapper.py in __getattr__(self, name)
#     104     if name.startswith('_dw_'):
#     105       raise AttributeError('Accessing local variables before they are created.')
# --> 106     attr = getattr(self._dw_wrapped_module, name)
#     107     if (self._dw_warning_count < _PER_MODULE_WARNING_LIMIT and
#     108         name not in self._dw_deprecated_printed):
#
# AttributeError: module 'tensorflow._api.v1.config' has no attribute 'list_physical_devices'

# %%
img1 = cv2.imread('./Test_ir/1.bmp',cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('./Test_ir/2.bmp', cv2.IMREAD_GRAYSCALE)
img26 = cv2.imread('./Test_ir/26.bmp', cv2.IMREAD_GRAYSCALE)
img3 = cv2.imread('./Test_ir/3.bmp', cv2.IMREAD_GRAYSCALE)

# %%
img = img26.copy()
clahe = cv2.createCLAHE(clipLimit = 5)
final_img = clahe.apply(img)

# %%
img26 = img26.astype(np.uint32)

# %%
img26.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img26,cmap='gray')
plt.show()
plt.imshow(img, cmap='gray')
plt.show()

# %%
img1_log = log_img(img1)
img2_log = log_img(img2)
img26_log = log_img(img26)
img3_log = log_img(img3)
# Out:
# d:\files\image fusion\Final-year-project-original\my_utils.py:8: RuntimeWarning: divide by zero encountered in log
#   log_image =  255 * (np.log(img + 1)) / np.log(1 + np.max(img))

# %%
# img1_n = normalize_image(img1_log)
# img2_n = normalize_image(img2_log)
# img26_n = normalize_image(img26_log)
# img3_n = normalize_image(img3_log)

# %%
plt.imshow(img26_log, cmap='gray')
plt.show()
# plt.imshow(img26_log * 255, cmap='gray')
# plt.show()

# %%
img26_log.dtype
# Out:
# dtype('uint8')

# %%
img26_log_255= np.array(img26_log*255, dtype = np.uint32)

# %%
plt.imshow(img26_log_255 * 255, cmap='gray')
plt.show()

# %%
clahe = cv2.createCLAHE(clipLimit = 3)
final_img = clahe.apply(img26_log)

# %%
plt.imshow(final_img, cmap='gray')

# %%
image = cv2.resize(img26_log_255, (500, 600))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11804\3194127591.py in <module>
# ----> 1 image = cv2.resize(img26_log_255, (500, 600))
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src data type = 8 is not supported
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
plt.imshow(img1_log,cmap='gray')
plt.show()
plt.imshow(img2_log,cmap='gray')
plt.show()
plt.imshow(img26_log,cmap='gray')
plt.show()
plt.imshow(img3_log,cmap='gray')
plt.show()

# %%
plt.imshow(img1_n,cmap='gray')
plt.show()
plt.imshow(img2_n,cmap='gray')
plt.show()
plt.imshow(img26_n,cmap='gray')
plt.show()
plt.imshow(img3_n,cmap='gray')
plt.show()

# %%
# Out:
# True
